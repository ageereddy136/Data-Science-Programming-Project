# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
from glob import glob
import seaborn as sns
from PIL import Image
np.random.seed(123)
from sklearn.preprocessing import label_binarize
from sklearn.metrics import confusion_matrix
import itertools

import keras
from keras.utils.np_utils import to_categorical # used for converting labels to one-hot-encoding
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D
from keras import backend as K
import itertools

from tensorflow.keras.layers import BatchNormalization
from tensorflow.keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ReduceLROnPlateau
from sklearn.model_selection import train_test_split

# %%
#1. Function to plot model's validation loss and validation accuracy
def plot_model_history(model_history):
    fig, axs = plt.subplots(1,2,figsize=(15,5))
    # summarize history for accuracy
    axs[0].plot(range(1,len(model_history.history['accuracy'])+1),model_history.history['accuracy'])
    axs[0].plot(range(1,len(model_history.history['val_accuracy'])+1),model_history.history['val_accuracy'])
    axs[0].set_title('Model Accuracy')
    axs[0].set_ylabel('Accuracy')
    axs[0].set_xlabel('Epoch')
    axs[0].set_xticks(np.arange(1,len(model_history.history['accuracy'])+1),len(model_history.history['accuracy'])/10)
    axs[0].legend(['train', 'val'], loc='best')
    # summarize history for loss
    axs[1].plot(range(1,len(model_history.history['loss'])+1),model_history.history['loss'])
    axs[1].plot(range(1,len(model_history.history['val_loss'])+1),model_history.history['val_loss'])
    axs[1].set_title('Model Loss')
    axs[1].set_ylabel('Loss')
    axs[1].set_xlabel('Epoch')
    axs[1].set_xticks(np.arange(1,len(model_history.history['loss'])+1),len(model_history.history['loss'])/10)
    axs[1].legend(['train', 'val'], loc='best')
    plt.show()

# %%
base_skin_dir = os.path.join('C:/','Users','vivek348','Pictures','DSP_Project','Image','input')

# Merging images from both folders HAM10000_images_part1.zip and HAM10000_images_part2.zip into one dictionary

imageid_path_dict = {os.path.splitext(os.path.basename(x))[0]: x
                     for x in glob(os.path.join(base_skin_dir, '*', '*.jpg'))}

# This dictionary is useful for displaying more human-friendly labels later on

lesion_type_dict = {
    'nv': 'Melanocytic nevi',
    'mel': 'Melanoma',
    'bkl': 'Benign keratosis-like lesions ',
    'bcc': 'Basal cell carcinoma',
    'akiec': 'Actinic keratoses',
    'vasc': 'Vascular lesions',
    'df': 'Dermatofibroma'
}

# %%
skin_df = pd.read_csv(os.path.join(base_skin_dir, 'HAM10000_metadata.csv'))

# Creating New Columns for better readability

skin_df['path'] = skin_df['image_id'].map(imageid_path_dict.get)
skin_df['cell_type'] = skin_df['dx'].map(lesion_type_dict.get) 
skin_df['cell_type_idx'] = pd.Categorical(skin_df['cell_type']).codes

# %%
# Now lets see the sample of tile_df to look on newly made columns
skin_df.head()
# Out:
#      lesion_id      image_id   dx dx_type   age   sex localization  \
# 0  HAM_0000118  ISIC_0027419  bkl   histo  80.0  male        scalp
# 1  HAM_0000118  ISIC_0025030  bkl   histo  80.0  male        scalp
# 2  HAM_0002730  ISIC_0026769  bkl   histo  80.0  male        scalp
# 3  HAM_0002730  ISIC_0025661  bkl   histo  80.0  male        scalp
# 4  HAM_0001466  ISIC_0031633  bkl   histo  75.0  male          ear
#
#                                                 path  \
# 0  C:/Users\vivek348\Pictures\DSP_Project\Image\i...
# 1  C:/Users\vivek348\Pictures\DSP_Project\Image\i...
# 2  C:/Users\vivek348\Pictures\DSP_Project\Image\i...
# 3  C:/Users\vivek348\Pictures\DSP_Project\Image\i...
# 4  C:/Users\vivek348\Pictures\DSP_Project\Image\i...
#
#                         cell_type  cell_type_idx
# 0  Benign keratosis-like lesions               2
# 1  Benign keratosis-like lesions               2
# 2  Benign keratosis-like lesions               2
# 3  Benign keratosis-like lesions               2
# 4  Benign keratosis-like lesions               2

# %%
skin_df.isnull().sum()
# Out:
# lesion_id         0
# image_id          0
# dx                0
# dx_type           0
# age              57
# sex               0
# localization      0
# path              0
# cell_type         0
# cell_type_idx     0
# dtype: int64

# %%
skin_df['age'].fillna((skin_df['age'].mean()), inplace=True)

# %%
skin_df.isnull().sum()
# Out:
# lesion_id        0
# image_id         0
# dx               0
# dx_type          0
# age              0
# sex              0
# localization     0
# path             0
# cell_type        0
# cell_type_idx    0
# dtype: int64

# %%
print(skin_df.dtypes)
# Out:
# lesion_id         object
# image_id          object
# dx                object
# dx_type           object
# age              float64
# sex               object
# localization      object
# path              object
# cell_type         object
# cell_type_idx       int8
# dtype: object

# %%
skin_df['path']=skin_df['path'].astype(object)

# %%
fig, ax1 = plt.subplots(1, 1, figsize= (10, 5))
skin_df['cell_type'].value_counts().plot(kind='bar', ax=ax1)
# Out:
# <AxesSubplot:>

# %%
skin_df['dx'].value_counts()
# Out:
# nv       6705
# mel      1113
# bkl      1099
# bcc       514
# akiec     327
# vasc      142
# df        115
# Name: dx, dtype: int64

# %%
# Separate majority and minority classes
from sklearn.utils import resample
skin_df_majority = skin_df[skin_df['dx']=='nv']
skin_df_minority = skin_df[skin_df['dx']!='nv']
 
# Downsample majority class
skin_df_majority_downsampled = resample(skin_df_majority, 
                                 replace=False,    
                                 n_samples=3000)
#Upsample minority class
skin_df_minority_upsampled = resample(skin_df_minority, 
                                 replace=True,     
                                 n_samples=5000)
# Combine minority class with downsampled majority class
skin_df_up_down_sampled = pd.concat([skin_df_majority_downsampled, skin_df_minority_upsampled])
skin_df_up_down_sampled['dx'].value_counts()
# Out:
# nv       3000
# bkl      1661
# mel      1654
# bcc       770
# akiec     518
# vasc      217
# df        180
# Name: dx, dtype: int64

# %%
skin_df=skin_df_up_down_sampled

# %%
skin_df['dx_type'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
skin_df['localization'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
skin_df['age'].hist(bins=40)
# Out:
# <AxesSubplot:>

# %%
skin_df['sex'].value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
sns.scatterplot('age','cell_type_idx',data=skin_df)
# Out:
# C:\Users\vivek348\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='age', ylabel='cell_type_idx'>

# %%
sns.factorplot('sex','cell_type_idx',data=skin_df)
# Out:
# C:\Users\vivek348\Anaconda3\lib\site-packages\seaborn\categorical.py:3714: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# C:\Users\vivek348\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
skin_df['image'] = skin_df['path'].map(lambda x: np.asarray(Image.open(x).resize((100,75))))

# %%
skin_df.head()
# Out:
#         lesion_id      image_id  dx    dx_type   age   sex     localization  \
# 8666  HAM_0005631  ISIC_0025492  nv      histo  55.0  male             back
# 8933  HAM_0006596  ISIC_0027005  nv      histo  35.0  male             back
# 8343  HAM_0002628  ISIC_0031204  nv      histo  50.0  male  lower extremity
# 8703  HAM_0004942  ISIC_0028202  nv      histo  75.0  male             back
# 6545  HAM_0002020  ISIC_0032301  nv  follow_up  50.0  male            trunk
#
#                                                    path         cell_type  \
# 8666  C:/Users\vivek348\Pictures\DSP_Project\Image\i...  Melanocytic nevi
# 8933  C:/Users\vivek348\Pictures\DSP_Project\Image\i...  Melanocytic nevi
# 8343  C:/Users\vivek348\Pictures\DSP_Project\Image\i...  Melanocytic nevi
# 8703  C:/Users\vivek348\Pictures\DSP_Project\Image\i...  Melanocytic nevi
# 6545  C:/Users\vivek348\Pictures\DSP_Project\Image\i...  Melanocytic nevi
#
#       cell_type_idx                                              image
# 8666              4  [[[196, 150, 133], [204, 150, 133], [204, 148,...
# 8933              4  [[[128, 110, 126], [130, 111, 129], [131, 112,...
# 8343              4  [[[184, 139, 143], [183, 138, 141], [186, 138,...
# 8703              4  [[[161, 136, 122], [163, 142, 131], [162, 142,...
# 6545              4  [[[200, 90, 113], [206, 97, 117], [209, 98, 11...

# %%
n_samples = 5
fig, m_axs = plt.subplots(7, n_samples, figsize = (4*n_samples, 3*7))
for n_axs, (type_name, type_rows) in zip(m_axs, 
                                         skin_df.sort_values(['cell_type']).groupby('cell_type')):
    n_axs[0].set_title(type_name)
    for c_ax, (_, c_row) in zip(n_axs, type_rows.sample(n_samples, random_state=1234).iterrows()):
        c_ax.imshow(c_row['image'])
        c_ax.axis('off')
fig.savefig('category_samples.png', dpi=300)

# %%
# Checking the image size distribution
skin_df['image'].map(lambda x: x.shape).value_counts()
# Out:
# (75, 100, 3)    8000
# Name: image, dtype: int64

# %%
features=skin_df.drop(columns=['cell_type_idx'],axis=1)
target=skin_df['cell_type_idx']

# %%
x_train_o, x_test_o, y_train_o, y_test_o = train_test_split(features, target, test_size=0.20,random_state=1234)

# %%
x_train = np.asarray(x_train_o['image'].tolist())
x_test = np.asarray(x_test_o['image'].tolist())

x_train_mean = np.mean(x_train)
x_train_std = np.std(x_train)

x_test_mean = np.mean(x_test)
x_test_std = np.std(x_test)

x_train = (x_train - x_train_mean)/x_train_std
x_test = (x_test - x_test_mean)/x_test_std

# %%
# Perform one-hot encoding on the labels
y_train = to_categorical(y_train_o, num_classes = 7)
y_test = to_categorical(y_test_o, num_classes = 7)

# %%
x_train, x_validate, y_train, y_validate = train_test_split(x_train, y_train, test_size = 0.2, random_state = 2)

# %%
x_train.shape[0]
# Out:
# 5120

# %%
# Reshape image in 3 dimensions (height = 75px, width = 100px , canal = 3)
x_train = x_train.reshape(x_train.shape[0], *(75, 100, 3))
x_test = x_test.reshape(x_test.shape[0], *(75, 100, 3))
x_validate = x_validate.reshape(x_validate.shape[0], *(75, 100, 3))

# %%
# Set the CNN model 
# my CNN architechture is In -> [[Conv2D->relu]*2 -> MaxPool2D -> Dropout]*2 -> Flatten -> Dense -> Dropout -> Out
input_shape = (75, 100, 3)
num_classes = 7

model = Sequential()
model.add(Conv2D(32, kernel_size=(3, 3),activation='relu',padding = 'Same',input_shape=input_shape))
model.add(Conv2D(32,kernel_size=(3, 3), activation='relu',padding = 'Same',))
model.add(MaxPool2D(pool_size = (2, 2)))
model.add(Dropout(0.25))

model.add(Conv2D(64, (3, 3), activation='relu',padding = 'Same'))
model.add(Conv2D(64, (3, 3), activation='relu',padding = 'Same'))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.20))

model.add(Conv2D(32, (3, 3), activation='relu',padding = 'Same'))
model.add(MaxPool2D(pool_size=(2, 2)))
model.add(Dropout(0.10))

model.add(Flatten())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 75, 100, 32)       896
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 75, 100, 32)       9248
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 37, 50, 32)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 37, 50, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 37, 50, 64)        18496
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 37, 50, 64)        36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 18, 25, 64)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 18, 25, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 18, 25, 32)        18464
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 9, 12, 32)         0
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 9, 12, 32)         0
# _________________________________________________________________
# flatten (Flatten)            (None, 3456)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               442496
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 7)                 903
# =================================================================
# Total params: 527,431
# Trainable params: 527,431
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Define the optimizer
optimizer = Adam(lr=0.001, beta_1=0.9, beta_2=0.999, epsilon=None, decay=0.0, amsgrad=False)
# Out:
# C:\Users\vivek348\Anaconda3\lib\site-packages\keras\optimizer_v2\optimizer_v2.py:355: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   warnings.warn(

# %%
# Compile the model
model.compile(optimizer = optimizer , loss = "categorical_crossentropy", metrics=["accuracy"])

# %%
# Set a learning rate annealer
learning_rate_reduction = ReduceLROnPlateau(monitor='val_acc', 
                                            patience=3, 
                                            verbose=1, 
                                            factor=0.5, 
                                            min_lr=0.00001)

# %%
# With data augmentation to prevent overfitting 

datagen = ImageDataGenerator(
        featurewise_center=False,  # set input mean to 0 over the dataset
        samplewise_center=False,  # set each sample mean to 0
        featurewise_std_normalization=False,  # divide inputs by std of the dataset
        samplewise_std_normalization=False,  # divide each input by its std
        zca_whitening=False,  # apply ZCA whitening
        rotation_range=10,  # randomly rotate images in the range (degrees, 0 to 180)
        zoom_range = 0.1, # Randomly zoom image 
        width_shift_range=0.1,  # randomly shift images horizontally (fraction of total width)
        height_shift_range=0.1,  # randomly shift images vertically (fraction of total height)
        horizontal_flip=False,  # randomly flip images
        vertical_flip=False)  # randomly flip images

datagen.fit(x_train)

# %%
# Fit the model
epochs = 50 
batch_size = 10
history = model.fit_generator(datagen.flow(x_train,y_train, batch_size=batch_size),
                              epochs = epochs, validation_data = (x_validate,y_validate),
                              verbose = 1, steps_per_epoch=x_train.shape[0] // batch_size
                               , callbacks=[learning_rate_reduction])
#history = model.fit(x_train,y_train, batch_size=batch_size,epochs = epochs, validation_data = (x_validate,y_validate),
 #                            verbose = 1, steps_per_epoch=x_train.shape[0] // batch_size
  #                          , callbacks=[learning_rate_reduction])
# Out:
# C:\Users\vivek348\Anaconda3\lib\site-packages\keras\engine\training.py:1972: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# Epoch 1/50
# 512/512 [==============================] - 93s 179ms/step - loss: 1.4324 - accuracy: 0.4330 - val_loss: 1.3126 - val_accuracy: 0.5164
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 2/50
# 512/512 [==============================] - 91s 177ms/step - loss: 1.2884 - accuracy: 0.4936 - val_loss: 1.1541 - val_accuracy: 0.5508
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 3/50
# 512/512 [==============================] - 92s 179ms/step - loss: 1.2212 - accuracy: 0.5287 - val_loss: 1.0435 - val_accuracy: 0.5852
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 4/50
# 512/512 [==============================] - 90s 176ms/step - loss: 1.1252 - accuracy: 0.5639 - val_loss: 1.0137 - val_accuracy: 0.6078
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 5/50
# 512/512 [==============================] - 90s 175ms/step - loss: 1.0668 - accuracy: 0.5770 - val_loss: 0.9754 - val_accuracy: 0.6156
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 6/50
# 512/512 [==============================] - 91s 177ms/step - loss: 1.0255 - accuracy: 0.5982 - val_loss: 0.9495 - val_accuracy: 0.6195
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 7/50
# 512/512 [==============================] - 90s 175ms/step - loss: 0.9973 - accuracy: 0.6082 - val_loss: 0.9576 - val_accuracy: 0.6398
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 8/50
# 512/512 [==============================] - 91s 177ms/step - loss: 0.9520 - accuracy: 0.6305 - val_loss: 0.8956 - val_accuracy: 0.6477
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 9/50
# 512/512 [==============================] - 91s 177ms/step - loss: 0.9249 - accuracy: 0.6357 - val_loss: 0.9068 - val_accuracy: 0.6453
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 10/50
# 512/512 [==============================] - 91s 177ms/step - loss: 0.9147 - accuracy: 0.6459 - val_loss: 0.8724 - val_accuracy: 0.6562
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 11/50
# 512/512 [==============================] - 91s 177ms/step - loss: 0.8636 - accuracy: 0.6586 - val_loss: 0.8393 - val_accuracy: 0.6625
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 12/50
# 512/512 [==============================] - 92s 179ms/step - loss: 0.8433 - accuracy: 0.6670 - val_loss: 0.8285 - val_accuracy: 0.6766
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 13/50
# 512/512 [==============================] - 90s 176ms/step - loss: 0.8185 - accuracy: 0.6721 - val_loss: 0.7968 - val_accuracy: 0.6805
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 14/50
# 512/512 [==============================] - 90s 176ms/step - loss: 0.8055 - accuracy: 0.6844 - val_loss: 0.7970 - val_accuracy: 0.6750
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 15/50
# 512/512 [==============================] - 91s 177ms/step - loss: 0.7907 - accuracy: 0.6770 - val_loss: 0.7763 - val_accuracy: 0.6852
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 16/50
# 512/512 [==============================] - 89s 174ms/step - loss: 0.7792 - accuracy: 0.6879 - val_loss: 0.7301 - val_accuracy: 0.7195
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 17/50
# 512/512 [==============================] - 88s 172ms/step - loss: 0.7565 - accuracy: 0.7006 - val_loss: 0.7469 - val_accuracy: 0.7000
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 18/50
# 512/512 [==============================] - 92s 179ms/step - loss: 0.7536 - accuracy: 0.7094 - val_loss: 0.7486 - val_accuracy: 0.7203
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 19/50
# 512/512 [==============================] - 91s 178ms/step - loss: 0.7369 - accuracy: 0.7100 - val_loss: 0.7137 - val_accuracy: 0.7242
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 20/50
# 512/512 [==============================] - 90s 177ms/step - loss: 0.7199 - accuracy: 0.7135 - val_loss: 0.7425 - val_accuracy: 0.7281
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 21/50
# 512/512 [==============================] - 91s 177ms/step - loss: 0.7046 - accuracy: 0.7236 - val_loss: 0.6860 - val_accuracy: 0.7281
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 22/50
# 512/512 [==============================] - 92s 180ms/step - loss: 0.6952 - accuracy: 0.7348 - val_loss: 0.7138 - val_accuracy: 0.7344
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 23/50
# 512/512 [==============================] - 91s 178ms/step - loss: 0.6836 - accuracy: 0.7324 - val_loss: 0.7239 - val_accuracy: 0.7484
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 24/50
# 512/512 [==============================] - 91s 178ms/step - loss: 0.6962 - accuracy: 0.7266 - val_loss: 0.6941 - val_accuracy: 0.7484
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 25/50
# 512/512 [==============================] - 91s 178ms/step - loss: 0.6483 - accuracy: 0.7443 - val_loss: 0.6730 - val_accuracy: 0.7461
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 26/50
# 512/512 [==============================] - 89s 175ms/step - loss: 0.6644 - accuracy: 0.7395 - val_loss: 0.7077 - val_accuracy: 0.7242
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 27/50
# 512/512 [==============================] - 89s 173ms/step - loss: 0.6285 - accuracy: 0.7537 - val_loss: 0.6870 - val_accuracy: 0.7508
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 28/50
# 512/512 [==============================] - 89s 174ms/step - loss: 0.6381 - accuracy: 0.7557 - val_loss: 0.6576 - val_accuracy: 0.7664
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 29/50
# 512/512 [==============================] - 90s 176ms/step - loss: 0.6261 - accuracy: 0.7545 - val_loss: 0.6923 - val_accuracy: 0.7484
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 30/50
# 512/512 [==============================] - 89s 174ms/step - loss: 0.6179 - accuracy: 0.7574 - val_loss: 0.6708 - val_accuracy: 0.7531
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 31/50
# 512/512 [==============================] - 89s 174ms/step - loss: 0.6076 - accuracy: 0.7588 - val_loss: 0.7518 - val_accuracy: 0.7305
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 32/50
# 512/512 [==============================] - 89s 174ms/step - loss: 0.5905 - accuracy: 0.7676 - val_loss: 0.6402 - val_accuracy: 0.7719
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 33/50
# 512/512 [==============================] - 89s 174ms/step - loss: 0.5834 - accuracy: 0.7738 - val_loss: 0.6755 - val_accuracy: 0.7539
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 34/50
# 512/512 [==============================] - 89s 173ms/step - loss: 0.5896 - accuracy: 0.7617 - val_loss: 0.6580 - val_accuracy: 0.7711
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 35/50
# 512/512 [==============================] - 91s 178ms/step - loss: 0.5794 - accuracy: 0.7758 - val_loss: 0.6337 - val_accuracy: 0.7734
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 36/50
# 512/512 [==============================] - 89s 174ms/step - loss: 0.5741 - accuracy: 0.7797 - val_loss: 0.6910 - val_accuracy: 0.7508
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 37/50
# 512/512 [==============================] - 89s 174ms/step - loss: 0.5695 - accuracy: 0.7785 - val_loss: 0.6563 - val_accuracy: 0.7547
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 38/50
# 512/512 [==============================] - 89s 173ms/step - loss: 0.5699 - accuracy: 0.7842 - val_loss: 0.6902 - val_accuracy: 0.7586
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 39/50
# 512/512 [==============================] - 89s 174ms/step - loss: 0.5568 - accuracy: 0.7846 - val_loss: 0.6486 - val_accuracy: 0.7609
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 40/50
# 512/512 [==============================] - 89s 173ms/step - loss: 0.5410 - accuracy: 0.7904 - val_loss: 0.6133 - val_accuracy: 0.7758
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 41/50
# 512/512 [==============================] - 89s 173ms/step - loss: 0.5319 - accuracy: 0.7893 - val_loss: 0.6355 - val_accuracy: 0.7805
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 42/50
# 512/512 [==============================] - 89s 173ms/step - loss: 0.5478 - accuracy: 0.7879 - val_loss: 0.6374 - val_accuracy: 0.7812
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 43/50
# 512/512 [==============================] - 89s 173ms/step - loss: 0.5331 - accuracy: 0.7994 - val_loss: 0.6274 - val_accuracy: 0.7758
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 44/50
# 512/512 [==============================] - 88s 172ms/step - loss: 0.5300 - accuracy: 0.7959 - val_loss: 0.6392 - val_accuracy: 0.7937
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 45/50
# 512/512 [==============================] - 88s 172ms/step - loss: 0.5385 - accuracy: 0.7943 - val_loss: 0.6154 - val_accuracy: 0.7969
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 46/50
# 512/512 [==============================] - 89s 173ms/step - loss: 0.5159 - accuracy: 0.7969 - val_loss: 0.6193 - val_accuracy: 0.7992
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 47/50
# 512/512 [==============================] - 88s 172ms/step - loss: 0.5051 - accuracy: 0.8068 - val_loss: 0.6029 - val_accuracy: 0.7961
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 48/50
# 512/512 [==============================] - 88s 172ms/step - loss: 0.5064 - accuracy: 0.8051 - val_loss: 0.5959 - val_accuracy: 0.7914
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 49/50
# 512/512 [==============================] - 88s 173ms/step - loss: 0.5071 - accuracy: 0.8037 - val_loss: 0.6239 - val_accuracy: 0.7844
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr
# Epoch 50/50
# 512/512 [==============================] - 89s 173ms/step - loss: 0.5111 - accuracy: 0.8029 - val_loss: 0.6397 - val_accuracy: 0.7844
# WARNING:tensorflow:Learning rate reduction is conditioned on metric `val_acc` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy,lr

# %%
loss, accuracy = model.evaluate(x_test, y_test, verbose=1)
loss_v, accuracy_v = model.evaluate(x_validate, y_validate, verbose=1)
print("Validation: accuracy = %f  ;  loss_v = %f" % (accuracy_v, loss_v))
print("Test: accuracy = %f  ;  loss = %f" % (accuracy, loss))
model.save("model.h5")
# Out:
# 50/50 [==============================] - 5s 105ms/step - loss: 0.6390 - accuracy: 0.7619
# 40/40 [==============================] - 4s 104ms/step - loss: 0.6397 - accuracy: 0.7844
# Validation: accuracy = 0.784375  ;  loss_v = 0.639710
# Test: accuracy = 0.761875  ;  loss = 0.639011

# %%
plot_model_history(history)
# Out:
# <ipython-input-65-6b7ad8b7a74f>:10: MatplotlibDeprecationWarning: Passing the minor parameter of set_ticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
#   axs[0].set_xticks(np.arange(1,len(model_history.history['accuracy'])+1),len(model_history.history['accuracy'])/10)
# <ipython-input-65-6b7ad8b7a74f>:18: MatplotlibDeprecationWarning: Passing the minor parameter of set_ticks() positionally is deprecated since Matplotlib 3.2; the parameter will become keyword-only two minor releases later.
#   axs[1].set_xticks(np.arange(1,len(model_history.history['loss'])+1),len(model_history.history['loss'])/10)

# %%
# Function to plot confusion matrix    
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# Predict the values from the validation dataset
Y_pred = model.predict(x_validate)
# Convert predictions classes to one hot vectors 
Y_pred_classes = np.argmax(Y_pred,axis = 1) 
# Convert validation observations to one hot vectors
Y_true = np.argmax(y_validate,axis = 1) 
# compute the confusion matrix
confusion_mtx = confusion_matrix(Y_true, Y_pred_classes)

 

# plot the confusion matrix
plot_confusion_matrix(confusion_mtx, classes = range(7))

# %%
label_frac_error = 1 - np.diag(confusion_mtx) / np.sum(confusion_mtx, axis=1)
plt.bar(np.arange(7),label_frac_error)
plt.xlabel('True Label')
plt.ylabel('Fraction classified incorrectly')
# Out:
# Text(0, 0.5, 'Fraction classified incorrectly')
